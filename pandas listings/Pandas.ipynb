# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 538.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/11.5 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.5 MB 9.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.5 MB 11.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/11.5 MB 14.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.5 MB 15.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

df.head()
# Out:
#      id                                               name  host_id  \
# 0  5456          Walk to 6th, Rainey St and Convention Ctr     8028
# 1  5769                                     NW Austin Room     8186
# 2  6413                      Gem of a Studio near Downtown    13879
# 3  6448  Secluded Studio @ Zilker - King Bed, Bright & ...    14156
# 4  8502                            Woodland Studio Lodging    25298
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0     Sylvia                  NaN          78702  30.26057  -97.73441
# 1  Elizabeth                  NaN          78729  30.45697  -97.78422
# 2       Todd                  NaN          78704  30.24885  -97.73587
# 3        Amy                  NaN          78704  30.26034  -97.76487
# 4      Karen                  NaN          78741  30.23466  -97.73682
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
 # The last 10 rows of the DataFramedf.tail(n = 10)
# Out:
#                         id                                               name  \
# 15421  1368842101958709336                          The Onyx Haus @ TheDomain
# 15422  1368876231630476942                       Austin's Most Memorable View
# 15423  1368903563240814787                                     Munson Retreat
# 15424  1368933607672795070                                     Room in Austin
# 15425  1368975199060212276                            Treehouse in the woods!
# 15426  1369030977278306490                                         Flex basic
# 15427  1369031004106068720  Stylish & Lux Stay | Walk to Top Eats & Pickle...
# 15428  1369057136333994471                   Hill Country Hideout-Pool-HotTub
# 15429  1369090281815642314  Vibrant East Austin Retreat Private 2 Bedroom ...
# 15430  1369133036341359961  Hot Tub & Pool, Stunning 4BD Near Domain & Cap...
#
#          host_id        host_name  neighbourhood_group  neighbourhood  \
# ...

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group  neighbourhood  \
# count  1.543100e+04  1.543100e+04                  0.0   15431.000000
# mean   5.649547e+17  1.729455e+08                  NaN   78724.371395
# std    5.299163e+17  1.910468e+08                  NaN      20.723928
# min    5.456000e+03  2.300000e+01                  NaN   78701.000000
# 25%    3.139013e+07  1.825323e+07                  NaN   78704.000000
# 50%    6.687025e+17  8.177234e+07                  NaN   78723.000000
# 75%    1.077367e+18  2.963348e+08                  NaN   78745.000000
# max    1.369973e+18  6.821464e+08                  NaN   78759.000000
#
#            latitude     longitude         price  minimum_nights  \
# count  15431.000000  15431.000000  11029.000000    15431.000000
# mean      30.279937    -97.750596    341.934627        7.714341
# std        0.063867      0.064620    797.943897       29.975846
# min       30.078440    -98.053350     13.000000        1.000000
# ...

# %%
df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15431 entries, 0 to 15430
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15431 non-null  int64
#  1   name                            15431 non-null  object
#  2   host_id                         15431 non-null  int64
#  3   host_name                       15410 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   15431 non-null  int64
#  6   latitude                        15431 non-null  float64
#  7   longitude                       15431 non-null  float64
#  8   room_type                       15431 non-null  object
#  9   price                           11029 non-null  float64
#  10  minimum_nights                  15431 non-null  int64
#  11  number_of_reviews               15431 non-null  int64
# ...

# %%
df.shape # Get the number of rows and columns
# Out:
# (15431, 18)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %%
df[['name']]
# Out:
#                                                     name
# 0              Walk to 6th, Rainey St and Convention Ctr
# 1                                         NW Austin Room
# 2                          Gem of a Studio near Downtown
# 3      Secluded Studio @ Zilker - King Bed, Bright & ...
# 4                                Woodland Studio Lodging
# ...                                                  ...
# 15426                                         Flex basic
# 15427  Stylish & Lux Stay | Walk to Top Eats & Pickle...
# 15428                   Hill Country Hideout-Pool-HotTub
# 15429  Vibrant East Austin Retreat Private 2 Bedroom ...
# 15430  Hot Tub & Pool, Stunning 4BD Near Domain & Cap...
#
# [15431 rows x 1 columns]

# %%
df[['name', 'neighbourhood_group']]
# Out:
#                                                     name  neighbourhood_group
# 0              Walk to 6th, Rainey St and Convention Ctr                  NaN
# 1                                         NW Austin Room                  NaN
# 2                          Gem of a Studio near Downtown                  NaN
# 3      Secluded Studio @ Zilker - King Bed, Bright & ...                  NaN
# 4                                Woodland Studio Lodging                  NaN
# ...                                                  ...                  ...
# 15426                                         Flex basic                  NaN
# 15427  Stylish & Lux Stay | Walk to Top Eats & Pickle...                  NaN
# 15428                   Hill Country Hideout-Pool-HotTub                  NaN
# 15429  Vibrant East Austin Retreat Private 2 Bedroom ...                  NaN
# 15430  Hot Tub & Pool, Stunning 4BD Near Domain & Cap...                  NaN
#
# [15431 rows x 2 columns]
